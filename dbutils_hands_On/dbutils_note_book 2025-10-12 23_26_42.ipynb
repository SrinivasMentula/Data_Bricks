# %%
# This is to  understannd the dbutils functionality in the data bricks

# %%
dbutils.help()

# %%
dbutils.notebook.help()

# %%
dbutils.widgets.text(name= "environment_name",defaultValue="dev")

# %%
env_value =dbutils.widgets.get(name="environment_name")
print(env_value )

# %%
dbutils.notebook.exit("This has been terminated by the exit command")
