# %%
note_book_path = "/Workspace/Users/sarathazurelearning@gmail.com/Data_Bricks/dbutils_hands_On/dbutils_note_book 2025-10-12 23_26_42"

# %%
# %run "/Workspace/Users/sarathazurelearning@gmail.com/Data_Bricks/dbutils_hands_On/dbutils_note_book 2025-10-12 23_26_42"

# %%
return_value = dbutils.notebook.run(note_book_path,60,arguments={"name":"Test_env"})

# %%
print(return_value)

# %%
dbutils.notebook.run(note_book_path,timeout_seconds=60,arguments={"environment_name":"Testing the execution"})
