# %%
try:
    dbutils.fs.ls("/mnt/imventorydeltatable")
    spark.sql(""" 
            CREATE TABLE IF  NOT EXISTS default.tbl_ioh_I2005_output 
            using DELTA
            LOCATION "/mnt/imventorydeltatable"
            TBLPROPERTIES (
                'delta.feature.allowColumnDefaults' = 'supported'
            );
              """)
except Exception as E:
    spark.sql("""
    CREATE TABLE IF  NOT EXISTS default.tbl_ioh_I0132_import(


 
    Created_Date           TIMESTAMP
        )
        using DELTA
                LOCATION "/mnt/imventorydeltatable"
                TBLPROPERTIES (
                    'delta.feature.allowColumnDefaults' = 'supported'
                )               
         """)
