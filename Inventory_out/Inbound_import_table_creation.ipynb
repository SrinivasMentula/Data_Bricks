# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
try:
    dbutils.fs.ls("/mnt/inventorycontainer/import_table/")

    spark.sql(""" 
             CREATE TABLE IF NOT EXISTS default.import_table
               USING DELTA
    LOCATION '/mnt/inventorycontainer/import_table/'

    """
    )
    print('table created with schema present in the file')

except Exception as E:
    spark.sql( """

             CREATE TABLE IF NOT EXISTS default.import_table (

        storeId int,
        article_number  INT,
        qty int,
        reported_date DATE
    )
    USING DELTA
    LOCATION '/mnt/inventorycontainer/import_table/'

    """

    )

    print('Theere is no file present the table created without metadata')

# %%
# %sql
drop table if exists import_table
