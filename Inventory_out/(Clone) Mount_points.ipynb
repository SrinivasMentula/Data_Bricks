# %%
# Service Principal Credentials 
client_id  = "89e803a4-7bd4-42f3-990d-f0d6276da4a5"
client_secret = "Z_l8Q~JBLJRUYNGMqEgulk6Ya9NnK0NA~5mVjbTc"

# %%
# Mounting the inbound storage account 
def mount_point_creation (client_id,client_secret,container_name):
    configs = {"fs.azure.account.auth.type": "OAuth",
            "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
            "fs.azure.account.oauth2.client.id": f"{client_id}",
            "fs.azure.account.oauth2.client.secret":f"{client_secret}",
            "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/bcc0152e-287e-4663-92b1-2fac8f6e3db7/oauth2/token"}

    mount_points = dbutils.fs.mounts()

    sources = [i.source for i in mount_points if i.source == f"abfss://{container_name}@regrsadls2dev.dfs.core.windows.net/" ]
    print(sources)

    if any(sources):
        print('The mount has existed')
    else:
        dbutils.fs.mount(
        source = f"abfss://{container_name}@regrsadls2dev.dfs.core.windows.net/",
        mount_point = f"/mnt/{container_name}",
        extra_configs = configs)

# %%
# Creating mount points 
# Inbound mount point
mount_point_creation(client_id=client_id,client_secret=client_secret,container_name="inbound")
# Delta table mount point
mount_point_creation(client_id=client_id,client_secret=client_secret,container_name="deltatable")
mount_point_creation(client_id=client_id,client_secret=client_secret,container_name="inventorycontainer")
