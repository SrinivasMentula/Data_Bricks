# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# %sql 
CREATE TABLE IF NOT EXISTS default.Inventory_output
(

  store_id int,
  item_number int,
  day1_qty int,
  day2_qty int,
  day3_qty int,
  day4_qty  int,
  day5_qty   int,
  day6_qty INT,
  day7_qty INT

)
using Delta 
LOCATION "/mnt/inventorycontainer/Inventory_output/"
